# %%
import pandas as pd

# %%
radar = pd.read_csv("./radars.csv")

# %%
groupby = radar[["vitesse_vehicules_legers_kmh", "annee_installation", "departement"]].groupby(["annee_installation","vitesse_vehicules_legers_kmh"]).count()
groupby.reset_index()
# Out:
#     annee_installation  vitesse_vehicules_legers_kmh  departement
# 0                 2003                          50.0            3
# 1                 2003                          70.0            8
# 2                 2003                          80.0            5
# 3                 2003                          90.0            8
# 4                 2003                         110.0            6
# 5                 2003                         130.0            3
# 6                 2004                          50.0            6
# 7                 2004                          70.0           21
# 8                 2004                          80.0           20
# 9                 2004                          90.0           15
# 10                2004                         110.0            6
# 11                2004                         130.0            2
# 12                2005                          30.0            2
# ...

# %%
len(radar.annee_installation.unique())
# Out:
# 16
